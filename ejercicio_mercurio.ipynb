# %%
'''
proporcion_mercurio = 3
peso = int(input('Ingrese su peso: '))
peso = peso / proporcion_mercurio
print(peso)
'''
peso = int(input('Ingrese su peso: '))
print('Tu peso de {} KG, en mercurio es: {}.'.format( str(peso),  str(  int(peso / 3)  )   ))
# Out:
# Tu peso de 70 KG, en mercurio es: 23.

# %%
user_product_1 = input('Ingrese su primer producto a comprar')
user_product_2 = input('Ingrese su segundo producto a comprar')
user_product_3 = input('Ingrese su tercer producto a comprar')

product_1 = 500
product_2 = 800
product_3 = 1200

suma_product = product_1 + product_2 + product_3

user_cuotas = int(input('Ingrese cantidad de cuotas'))

cuotas_3_inicial = suma_product / 3
interes_cuota_3 = ((suma_product * 15) / 100)
cuotas_3 = cuotas_3_inicial + interes_cuota_3

cuotas_6_inicial = suma_product / 6
interes_cuota_6 = ((suma_product * 20) / 100)
cuotas_6 = cuotas_6_inicial + interes_cuota_6

cuotas_12_inicial = suma_product / 12
interes_cuota_12 = ((suma_product * 25) / 100)
cuotas_12 = cuotas_12_inicial + interes_cuota_12

def cuot_3(cuotas_3):
    if cuotas_3 == cuotas_3:
        return True
    else:
        return False
print('Usted compro los productos en tres cuotas por el valor de')
print(cuotas_3)

def cuot_2(cuotas_6):
    if cuotas_6 == cuotas_6:
        return True
    else:
        return False
print('Usted compro los productos en seis cuotas por el valor de')
print(cuotas_6)

def cuot_12(cuotas_12):
    if cuotas_12 == cuotas_12:
        return True
    else:
        return False
print('Usted compro los productos en doce cuotas por el valor de')
print(cuotas_12)

# %%
'''
Calculador gastos

Crear un programa que pida al usuario cuanto dinero disponible tiene, 
y vaya preguntando cuánto tiene que pagar por cada servicio, 
pidiendo el nombre del servicio y el monto a pagar, uno a la vez. 
Cada vez que pide ingresar un nuevo servicio, 
el mensaje debe mostrar cuántos servicios quedan por ingresar, 
utilizando una variable, y mostrar cuánto dinero disponible queda. 
Al final debe mostrar una lista con todos los servicios a pagar y el monto de cada uno, 
además del dinero disponible que le queda. Hacerlo con 3 servicios.

luz: $500
gas: $400

'''



dinero_disponible = int(input('Seleccione cantidad de dinero disponible'))

user_monto_gas = int(input('Ingrese cantidad a pagar de gas'))
user_monto_luz = int(input('Ingrese cantidad a pagar de luz'))
user_monto_agua = int(input('Ingrese cantidad a pagar de agua'))

user_dinero_ingresado = int(input('Ingrese la cantidad de dinero ingresado anteriormente'))

gas = 'gas'
luz= 'luz'
agua = 'agua'
total_service = gas + ',' + luz + 'y' + agua

mi_lista = ['gas',user_monto_gas, 'luz',user_monto_luz, 'agua',user_monto_agua]

# hardcode

a = gas + luz
b = gas + agua
c = gas
d = luz + agua
e = luz
f = agua
g = gas + luz + agua

a = user_monto_gas + user_monto_luz
b = user_monto_gas + user_monto_agua
c = user_monto_gas
d = user_monto_luz + user_monto_agua
e = user_monto_luz
f = user_monto_agua
g = user_monto_gas + user_monto_luz + user_monto_agua

lista_mia = (a, b, c, d, e, f, g) # Es una tupla

def servicios_ingresados(a, b ,c, d, e, f, g):
    if servicios_ingresados == a: # ES IGUAL
        return True
    if servicios_ingresados == b:
        return True
    if servicios_ingresados == c:
        return True
    if servicios_ingresados == d:
        return True
    if servicios_ingresados == e:
        return True
    if servicios_ingresados == f:
        return True
    if servicios_ingresados == g:
        return True
    else:
        return False
print(servicios_ingresados)

servicios_totales = user_monto_gas + user_monto_luz + user_monto_agua

no_ingresados = dinero_disponible - user_dinero_ingresado

print('Usted pago los siguientes servicios {}'.format(total_service))
print('Y le queda disponible de dinero: {}'.format(no_ingresados))
print(servicios_ingresados)

'''__________________________________
Seleccione cantidad de dinero disponible4000
Ingrese cantidad a pagar de gas200
Ingrese cantidad a pagar de luz1500
Ingrese la cantidad de dinero ingresado anteriormente1900
<function servicios_ingresados at 0x0000029252113E20>
Usted pago los siguientes servicios: gas,luzyagua
Y le queda disponible de dinero: 2100
<function servicios_ingresados at 0x0000029252113E20>
PS C:\Users\Hp\Desktop\NOELI PYTHON> & C:/Users/Hp/AppData/Local/Programs/Python/Python310/python.exe "c:/Users/Hp/Desktop/NOELI PYTHON/EJERCICIOS TEMA 1"
Seleccione cantidad de dinero disponible4000
Ingrese cantidad a pagar de gas200
Ingrese cantidad a pagar de luz1500
Ingrese cantidad a pagar de agua200
Ingrese la cantidad de dinero ingresado anteriormente1900
<function servicios_ingresados at 0x00000198DC863E20>
Hola
Profe Jeremias, este me salio aunque no me imprime el True ninguno de ellos.
'''
